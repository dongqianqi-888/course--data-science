# %%
print('hello world')
# Out:
# hello world

# %%
print('hi all')
# Out:
# hi all

# %%
print(23)
# Out:
# 23

# %% [markdown]
# # my first class

# %% [markdown]
# ## subsection

# %%
from openyxl import Workbook,load_workbook
from openyxl.styles import *
import warnings
warning.filterwarnings('ignore')
