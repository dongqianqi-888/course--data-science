# %%
import module

# %%
from module import *

# %%
make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
nameAge('donna',22)
# Out:
# Hi, I am donna
# My age is 22

# %% [markdown]
# # class

# %%
import ccar

# %%
from ccar import *

# %%
c1=car('audi','a4',2016)
print(c1.descriptive())
# Out:
# 2016 Audi A4

# %%
c1.read_odometer()
# Out:
# this car has 0 miles on it.

# %%
c1.odometer_reading=23  
c1.read_odometer()
# Out:
# this car has 23 miles on it.

# %%
c1.update_odometer(44)
c1.read_odometer()
# Out:
# this car has 44 miles on it.

# %%
c1.increment_odometer(20)
c1.read_odometer()
# Out:
# this car has 64 miles on it.

# %%
c2=electriccar('tesla','model s',2016)
print(c2.descriptive())
c2.describe_battery()
# Out:
# 2016 Tesla Model S
# this car has a 70-kWh battery.

# %% [markdown]
# # file and exception

# %%
with open('pi.txt') as file_object:
    context=file_object.read()
    print(context)
# Out:
# 3.141592653589793238462643383279

# %%
with open('C:/Users/dell/Desktop/pi.txt') as file:
    print(file.read())
# Out:
# 3.141592653589793238462643383279

# %%
filename='note'
with open(filename,'w') as file1:
    file1.write('i love python.\n')
    file1.write('i love python so much.\n')

# %%
with open(filename,'a') as file1:
    file1.write('i love python.\n')
    file1.write('i love python so much.\n')

# %%
try:
    print(5/0)
except ZeroDivisionError:
    print("you can't divide by 0!")
# Out:
# you can't divide by 0!
