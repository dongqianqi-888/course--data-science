# %% [markdown]
# ## 3-4. Guest List:
# If you could invite anyone, living or deceased, to dinner, who
# would you invite? Make a list that includes at least three people you’d like to
# invite to dinner . Then use your list to print a message to each person, inviting
# them to dinner

# %%
list=['zahra','mica','cici']
for mem in list:
    print('Hello '+mem+'! How are you~\n\tDo you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!\nFrom donna\n')
# Out:
# Hello zahra! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# From donna
#
# Hello mica! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# From donna
#
# Hello cici! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# From donna

# %% [markdown]
# ## 3-5. Changing Guest List: You just heard that one of your guests can’t make the dinner, so you need to send out a new set of invitations . You’ll have to think of someone else to invite.
#
#
# -	Start with your program from Exercise 3-4 . Add a print statement at the end of your program stating the name of the guest who can’t make it .
# -	Modify your list, replacing the name of the guest who can’t make it with the name of the new person you are inviting .
# -	Print a second set of invitation messages, one for each person who is still in your list

# %%
list=['zahra','mica','cici']
for mem in list:
    print('\nHello '+mem+'! How are you~\n\tDo you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!'+

          '\n\tI am soory to inform you cici would not attend our dinner. She needs a rest because of data the science course, which is exactly a heavy task.\n\nFrom donna\n')
# Out:
# Hello zahra! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# 	I am soory to inform you cici would not attend our dinner. She needs a rest because of data the science course, which is exactly a heavy task.
#
# From donna
#
#
# Hello mica! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# 	I am soory to inform you cici would not attend our dinner. She needs a rest because of data the science course, which is exactly a heavy task.
#
# From donna
#
#
# Hello cici! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner. I am looking forward to your coming!
# 	I am soory to inform you cici would not attend our dinner. She needs a rest because of data the science course, which is exactly a heavy task.
#
# From donna

# %%
list.append('lucxy')
for mem in list:
    print('Hello '+mem+'! How are you~\n\tDo you have time in Sunday evening this week? I sincerely invite you to my home for dinner.\n\tOur list have a change, so I send this message again. If you accepted the invition before, please have ignored this time.\n\tAnyway, I am looking forward to your coming!\nFrom donna\n')
# Out:
# Hello zahra! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner.
# 	Our list have a change, so I send this message again. If you accepted the invition before, please have ignored this time.
# 	Anyway, I am looking forward to your coming!
# From donna
#
# Hello mica! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner.
# 	Our list have a change, so I send this message again. If you accepted the invition before, please have ignored this time.
# 	Anyway, I am looking forward to your coming!
# From donna
#
# Hello cici! How are you~
# 	Do you have time in Sunday evening this week? I sincerely invite you to my home for dinner.
# 	Our list have a change, so I send this message again. If you accepted the invition before, please have ignored this time.
# 	Anyway, I am looking forward to your coming!
# From donna
#
# Hello lucxy! How are you~
# ...

# %% [markdown]
# ## 4-2. Animals: Think of at least three different animals that have a common characteristic . Store the names of these animals in a list, and then use a for loop to print out the name of each animal .
#  -	Modify your program to print a statement about each animal, such as A dog would make a great pet.
#  -	Add a line at the end of your program stating what these animals have in common . You could print a sentence such as Any of these animals would make a great pet

# %%
animal=['cat','dog','lamp','pig']
for a in animal:
    print('Donna like a '+a+', she really like wondering in UKM.')

print('Any sides of Donna is energetic!')
# Out:
# Donna like a cat, she really like wondering in UKM.
# Donna like a dog, she really like wondering in UKM.
# Donna like a lamp, she really like wondering in UKM.
# Donna like a pig, she really like wondering in UKM.
# Any sides of Donna is energetic!

# %% [markdown]
# ## 5-6. Stages of Life: Write an if-elif-else chain that determines a person’s stage of life . Set a value for the variable age, and then:
#
#  -	If the person is less than 2 years old, print a message that the person is a baby .
#  -	If the person is at least 2 years old but less than 4, print a message that the person is a toddler .
#
#  -	If the person is at least 4 years old but less than 13, print a message that the person is a kid .
#  -	If the person is at least 13 years old but less than 20, print a message that the person is a teenager .
#  -	If the person is at least 20 years old but less than 65, print a message that the person is an adult .
#  -	If the person is age 65 or older, print a message that the person is an elder

# %%
ages=[24,67,1,2,57,4,99,24]
for age in ages:
    if age<2:
        print('The person is a baby.')
    elif 2<=age<4:
        print('The person is a toddler.')
    elif 4<=age<13:
        print('The person is a kid.')
    elif 13<-age<20:
        print('The person is a teenager.')
    elif 20<=age<65:
        print('The person is an adult.')
    else:
        print('The person is an elder.')
# Out:
# The person is an adult.
# The person is an elder.
# The person is a baby.
# The person is a toddler.
# The person is an adult.
# The person is a kid.
# The person is an elder.
# The person is an adult.

# %% [markdown]
# ##  6-1. Person: Use a dictionary to store information about a person you know .
# Store their first name, last name, age, and the city in which they live . You
# should have keys such as first_name, last_name, age, and city . Print each
# piece of information stored in your dictionary .

# %%
di={'first_name':['dong','zhang','hu'],
    'last_name':['qianqi','ruixuan','chuchu'],
    'age':['22','26','23'],
    'city':['lanzhou','jingdezhen','ningbo']}
di['last_name']
# Out:
# ['qianqi', 'ruixuan', 'chuchu']
